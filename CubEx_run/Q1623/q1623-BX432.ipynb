# %%
import os
import numpy as np
import glob
import kcwi
import pdb
import importlib

# %reload_ext autoreload
# %autoreload
# %matplotlib inline

from IPython.display import Audio
sound_file = '/scr/yuguangchen/beep-01a.wav'

# %%
fn='q1623-BX432.list'

# %%
kcwi.kcwi_align(fn,noalign=True)
# Out:
# kb200821_00044_icubes.fits
# kb200821_00045_icubes.fits
# kb200821_00046_icubes.fits
# kb200822_00040_icubes.fits
# kb200822_00041_icubes.fits
# kb200822_00042_icubes.fits
# kb200822_00043_icubes.fits
# kb200822_00044_icubes.fits
# kb200822_00045_icubes.fits
# kb200822_00046_icubes.fits
# kb200822_00047_icubes.fits
# kb200822_00048_icubes.fits
# kb210706_00051_icubes.fits
# kb210706_00052_icubes.fits
# kb210905_00049_icubes.fits
# kb210905_00050_icubes.fits
# kb210905_00051_icubes.fits
# kb210905_00052_icubes.fits

# %%
kcwi.kcwi_align(fn)
# Out:
# kb200821_00044_icubes.fits
# kb200821_00045_icubes.fits
# -0.16227412311621237 0.4661949474273399
# kb200821_00046_icubes.fits
# 1.2014517749986489 -4.677115601767255
# kb200822_00040_icubes.fits
# -1.236687794508473 -3.7065450067220596
# kb200822_00041_icubes.fits
# -1.1931044759118699 -2.8225544460569907
# kb200822_00042_icubes.fits
# 0.5699610799161796 0.2649077354285865
# kb200822_00043_icubes.fits
# 0.883679050025826 0.9267456908691543
# kb200822_00044_icubes.fits
# 1.174082951633597 -0.009593164203948845
# kb200822_00045_icubes.fits
# -0.4146078646239211 -5.171171932139515
# kb200822_00046_icubes.fits
# -0.8392258609434471 -4.426397284627086
# kb200822_00047_icubes.fits
# -0.8458611387498216 -4.212104329008454
# kb200822_00048_icubes.fits
# -0.27203451942475 1.7410314810142822
# kb210706_00051_icubes.fits
# 1.6048066854598488 -0.14508998637448656
# kb210706_00052_icubes.fits
# -0.9339020024286739 -4.251834508303077
# kb210905_00049_icubes.fits
# 1.1004037293212647 4.460433050871153
# kb210905_00050_icubes.fits
# 1.7978310702590576 2.9305916382692985
# kb210905_00051_icubes.fits
# -0.009495166582091485 -8.156922629925397
# kb210905_00052_icubes.fits
# -0.9247252536373622 -7.458839124640306

# %%
kcwi.kcwi_check_flux(fn)

# %%
kcwi.kcwi_stack(fn,overwrite=True)
# Out:
# Projecting...
# kb200821_00044_icubes.fits
#      Vcorr = 23.719896539886328 km / s
#      EXPTIME = 1200.0
# kb200821_00045_icubes.fits
#      Vcorr = 23.715333871744743 km / s
#      EXPTIME = 1200.0
# kb200821_00046_icubes.fits
#      Vcorr = 23.70743848298476 km / s
#      EXPTIME = 1200.0
# kb200822_00040_icubes.fits
#      Vcorr = 23.427828825370558 km / s
#      EXPTIME = 1200.0
# kb200822_00041_icubes.fits
#      Vcorr = 23.440011403460524 km / s
#      EXPTIME = 1200.0
# kb200822_00042_icubes.fits
#      Vcorr = 23.449181854045335 km / s
#      EXPTIME = 1200.0
# kb200822_00043_icubes.fits
#      Vcorr = 23.455241702200492 km / s
#      EXPTIME = 1200.0
# kb200822_00044_icubes.fits
#      Vcorr = 23.458056182651028 km / s
#      EXPTIME = 1200.0
# kb200822_00045_icubes.fits
#      Vcorr = 23.45761441261157 km / s
#      EXPTIME = 1200.0
# kb200822_00046_icubes.fits
#      Vcorr = 23.453886625337027 km / s
#      EXPTIME = 1200.0
# kb200822_00047_icubes.fits
#      Vcorr = 23.44687228061091 km / s
#      EXPTIME = 1200.0
# kb200822_00048_icubes.fits
#      Vcorr = 23.43629487221213 km / s
#      EXPTIME = 900.0
# kb210706_00051_icubes.fits
#      Vcorr = 27.54477859676627 km / s
#      EXPTIME = 1200.0
# kb210706_00052_icubes.fits
#      Vcorr = 27.570662108771653 km / s
#      EXPTIME = 1200.0
# kb210905_00049_icubes.fits
#      Vcorr = 19.237735901676842 km / s
#      EXPTIME = 1200.0
# kb210905_00050_icubes.fits
#      Vcorr = 19.240647342056615 km / s
#      EXPTIME = 1200.0
# kb210905_00051_icubes.fits
#      Vcorr = 19.24064607569806 km / s
#      EXPTIME = 1200.0
# kb210905_00052_icubes.fits
#      Vcorr = 19.23722059283283 km / s
#      EXPTIME = 1200.0
# Stacking...
#   3%|▎         | 3/100 [00:00<00:04, 21.93it/s]/scr/yuguangchen/Soft/py/kcwi/kcwi.py:1073: RuntimeWarning: invalid value encountered in true_divide
#   data_3d[ii,:,:]=np.transpose(np.nansum(img*weight,axis=0)/np.nansum(weight,axis=0))
# /scr/yuguangchen/Soft/py/kcwi/kcwi.py:1074: RuntimeWarning: invalid value encountered in true_divide
#   vdata_3d[ii,:,:]=np.transpose(np.nansum(weight**2*var,axis=0)/np.nansum(weight,axis=0)**2)
# 100%|██████████| 100/100 [00:36<00:00,  2.76it/s]

# %%
kcwi.kcwi_astrometry(fn)
Audio(sound_file, autoplay=True)
# Out:
# q1623-BX432.list
# Iter: 1/2
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 '
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# Iter: 2/2
# 0.0 -0.5
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
